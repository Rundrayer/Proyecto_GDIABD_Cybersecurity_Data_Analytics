# %%
#IMPORTACION DE LIBRERIAS

from pathlib import Path
import pandas as pd
import numpy as np
import hashlib
import zipfile

# %%
#IMPORTAR CONFIGURACION DE RUTAS 

from Configuracion import CARGADOS, PROCESADOS, CSV_GENERADOS, IMPLEMENTACION_GOBERNANZA, ANALITICOS_PARQUET, ANALITICOS_RESULTADOS
from Configuracion import RECURSOS

# %%
#Prueba de rutas

print("--- VERIFICACIÓN DE RUTAS ---")
print(f"¿Encuentra la carpeta Recursos? : {RECURSOS.exists()}")
print(f"¿Encuentra la carpeta Cargados? : {CARGADOS.exists()}")
print(f"¿Encuentra la carpeta CSV?      : {CSV_GENERADOS.exists()}")
# Out:
# --- VERIFICACIÓN DE RUTAS ---
# ¿Encuentra la carpeta Recursos? : True
# ¿Encuentra la carpeta Cargados? : True
# ¿Encuentra la carpeta CSV?      : True

# %%
#DESCOMPRESION DE ORIGEN DE DATOS


# !!! Asegurarse de tener en la carpeta Recursos el dataset con el nombre "cybersecurity_intrusion_data"

#Creacion de ruta
Carpeta_Origen_zip = RECURSOS / "cybersecurity_intrusion_data.zip"

#se descomprime usando la libreria zipfile
#with zipfile.ZipFile(Carpeta_Origen_zip, 'r') as zip_ref:
#    zip_ref.extractall(CARGADOS)

#print(f"*** Dataset descomprimido en ruta actual: {CARGADOS} ***")
